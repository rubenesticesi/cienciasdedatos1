# %% [markdown]
# <a href="https://colab.research.google.com/github/rubenesticesi/cienciasdedatos1/blob/master/PredicciondeAutismo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PREDICCION** **DEL TRASTORNO DEL ESPECTRO AUTISMO- TEA**
#
# ### El trastorno del espectro autista es una afección relacionada con el desarrollo del cerebro que afecta la manera en la que una persona percibe y socializa con otras personas, lo que causa problemas en la interacción social y la comunicación. El trastorno también comprende patrones de conducta restringidos y repetitivos. El término «espectro» en el trastorno del espectro autista se refiere a un amplio abanico de síntomas y gravedad.
#
# Ref : https://www.mayoclinic.org/es/diseases-conditions/autism-spectrum-disorder/symptoms-causes/syc-20352928
#
# Cuaderno Desarrollado por :
#
# **RUBEN DARIO SABOGAL URBANO**

# %% [markdown]
# ![f0003404.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # CONJUNTO DE DATOS
# El conjunto de Datos , proviene de:
# https://www.kaggle.com/datasets/andrewmvd/autism-screening-on-adults
#
# https://archive.ics.uci.edu/dataset/426/autism+screening+adult
#
# para los cuales se procede a hacer su tratamiento, la cual es la Lista de verificacion Modificada para el autismo en niños pequeños, revisada M-CHAT-R.
#
# El principal test de cribado para la detección temprana del autismo en niños pequeños es la **Lista de Verificación Modificada para el Autismo en Niños Pequeños, Revisada (M-CHAT-R)**, un **cuestionario de 20 preguntas** que los padres o cuidadores completan para identificar posibles señales de autismo. Para adultos y niños mayores, existen otras herramientas como el Autism Quotient (AQ) o la Escala de Diagnóstico de Autismo y Asperger de Ritvo (RAADS-14)>>, que evalúan habilidades de lenguaje, interacción social e intereses.
#
# # M-CHAT-R
# La lista de verificación modificada para autismo en niños pequeños, revisada (M-CHAT-R) es una evaluación que hace una serie de 20 preguntas sobre el comportamiento de su hijo/a. Es administrado para niños pequeños entre 16 y 30 meses de edad. Los resultados le permitirán saber si es necesario una evaluación adicional.

# %% [markdown]
# ![M-CHAT-R.png](data:image/png;base64,...)

# %% [markdown]
# # ANALISIS UNIVARIADO DE UNA VARIABLE DEL DATASET CRIBADO O TEST DE AUTISMO
#
# Cuando inicias un nuevo proyecto de datos, los datos que adquieres rara vez son perfectos para tu análisis desde el principio. Esto hace que sea esencial que realices el proceso de limpieza de tus datos al inicio de cada nuevo proyecto.
#
# Limpiar tus datos es un proceso de eliminación de errores, valores atípicos e incoherencias, y de garantía de que todos tus datos están en un formato adecuado para tu análisis. Los datos que contienen muchos errores o que no han pasado por este proceso de limpieza de datos se denominan datos sucios
#
# ```
# # Esto tiene formato de código
# ```

# %%
## Importar las librerias necesarias para visualizacion de datos

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Leer Datos usando read_csv()function
df=pd.read_csv('autism_screening.csv')

# %%
# Display el Data_Frame "autism_screning" o Prueba de Deteccion de Autismo(cribado)
df
# Out:
#      A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0           1         1         1         1         0         0         1
# 1           1         1         0         1         0         0         0
# 2           1         1         0         1         1         0         1
# 3           1         1         0         1         0         0         1
# 4           1         0         0         0         0         0         0
# ..        ...       ...       ...       ...       ...       ...       ...
# 699         0         1         0         1         1         0         1
# 700         1         0         0         0         0         0         0
# 701         1         0         1         1         1         0         1
# 702         1         0         0         1         1         0         1
# 703         1         0         1         1         1         0         1
#
#      A8_Score  A9_Score  A10_Score  ...  gender       ethnicity jundice  \
# ...

# %% [markdown]
# Ahora es necesario inspeccionar los tipos de datos de las variables, para determinar los métodos adecuados para la visualización de datos mediante análisis univariado.

# %%
# Encontrar los tipos de Datos de las Variables en el DataFrame
# La propiedad .dtypes se utiliza para conocer los tipos de datos de las variables del conjunto de datos

df.dtypes
# Out:
# A1_Score             int64
# A2_Score             int64
# A3_Score             int64
# A4_Score             int64
# A5_Score             int64
# A6_Score             int64
# A7_Score             int64
# A8_Score             int64
# A9_Score             int64
# A10_Score            int64
# age                float64
# gender              object
# ethnicity           object
# jundice             object
# austim              object
# contry_of_res       object
# used_app_before     object
# result             float64
# age_desc            object
# relation            object
# Class/ASD           object
# dtype: object

# %% [markdown]
# #1.Descripcion de la Importancia de la Columna
# ##  Variable Relevante del Test de Cribado para Autismo
# La variable más relevante en este conjunto de datos es **A9_Score**, ya que presenta la mayor puntuación de información mutua respecto de la variable objetivo (diagnóstico de autismo). Esta variable representa una pregunta específica del test de screening y tiene la máxima capacidad para distinguir entre individuos con y sin autismo según los datos
#
# La importancia de A9_Score radica en que este tipo de puntaje proviene de una pregunta clave del cuestionario de tamizaje de autismo. Si una pregunta logra diferenciar mejor entre casos positivos y negativos (ASD), será relevante para todos los análisis posteriores y puede guiar la optimización del test, el diseño de preguntas clave, y la toma de decisiones clínicas o de salud pública

# %% [markdown]
# ## Significado de cada Variable del Test de Cribado
#
# Cada variable del conjunto de datos de cribado de autismo representa diferentes aspectos demográficos, clínicos y puntajes de la prueba aplicada a pacientes adultos. La relevancia de cada variable respecto al diagnóstico de autismo se estima principalmente por su capacidad para distinguir entre casos positivos y negativos (ASD)
#
# ** Significado de cada variable **
# A1_Score a A10_Score: Puntajes individuales para cada una de las 10 preguntas del test de cribado de autismo. Cada pregunta aborda síntomas o conductas típicas relacionadas con el espectro autista (dificultades sociales, rutinas, comunicación, etc.) y tienen valores binarios (0/1).
#
# **age**: Edad del paciente en años.
#
# **gender**: Género del paciente (f para femenino, m para masculino).
#
# **ethnicity**: Grupo étnico autorreportado.
#
# **jundice**: Si el paciente tuvo ictericia al nacer (“yes” o “no”), condición que algunos estudios asocian con riesgo neurológico.
#
# **austim**: Indica diagnóstico previo (“yes” o “no”).
#
# **contry_of_res**: País de residencia del paciente.
#
# **used_app_before**: Si el paciente ha usado antes la aplicación de cribado (“yes” o “no”).
#
# **result**: Puntaje total obtenido en el test, suma de las preguntas A1-A10.
#
# **age_desc**: Rango de edad categórico (“18 and more”), útil para segmentar resultados.
#
# **relation**: Relación del respondiente respecto al paciente (Self, Parent, Relative, Health care professional, Others).
#
# **Class/ASD**: Variable objetivo; indica si el paciente fue clasificado como Autismo (“YES”) o no (“NO”) tras el cribado.

# %% [markdown]
# # Variables ordenadas por importancia ascendente
#
# En el análisis de importancia por información mutua respecto al diagnóstico (ASD), estas variables numéricas del test suelen aportar más valor que las demográficas. Ordenadas por relevancia ascendente (de menor a mayor capacidad predictiva según el análisis con mutual information):
#
# **A6_Score**: Puntaje específico de la pregunta 6, menor capacidad para distinguir casos ASD.
#
# **A9_Score**: Pregunta 9, destaca como relevante pero no la más baja.
#
# **A7_Score, A2_Score, A3_Score, A4_Score, A5_Score**: Preguntas de puntaje medio en relevancia, aportan algo al modelo pero no son claves individuales.
#
# **age**: Edad, asociada pero con impacto menor comparado a los puntajes de screening.
#
# **A1_Score, A8_Score, A10_Score**: Preguntas cuya respuesta se correlaciona más fuertemente con el diagnóstico positivo.
#
# **result**: Puntaje total, generalmente muy correlacionado con la clasificación final pero es resultado más que predictor.
#
# **Las variables categóricas y demográficas (“gender”, “ethnicity”, “jundice”, “used_app_before”, “contry_of_res”, “relation”)** suelen tener menor importancia estadística directa para predecir autismo comparadas con los puntajes de screening, aunque pueden ser relevantes en estudios poblacionales o para ajustar efectos (aquello que sigue por virtud de una causa) de confusión

# %% [markdown]
# Los gráficos ayudan a comprender la ubicación de las observaciones en la variable de datos, su distribución y dispersión
# Los gráficos univariados son de dos tipos: 1) Gráficos enumerativos y 2) Gráficos de resumen.

# %% [markdown]
# # 2. Analysis Univariado en Python
# **El análisis estadístico univariado** en ciencia de datos es el análisis de una única variable a la vez para describir sus características principales, distribuciones de frecuencia y patrones. A diferencia de otros análisis, se enfoca en entender cada variable de forma aislada, sin investigar sus relaciones o causas con otras variables. Se utilizan herramientas como la media, mediana, moda, desviación estándar, histogramas y tablas de frecuencia para resumir y describir los datos.
#
# **Objetivos principales**
#
# **-Describir los datos**: El objetivo principal es resumir y describir las características de una sola variable.
#
# **-Identificar patrones**: Ayuda a descubrir patrones dentro de los datos de esa variable.
#
# **-Comprender la distribución**: Revela cómo se distribuyen los valores de la variable.
# ¿Cuándo se utiliza?
# Cuando necesitas entender las características individuales de cada variable en un conjunto de datos.
# Es la forma más simple de análisis de datos.
# ## Generar Estadisticas Descriptivas en Python

# %% [markdown]
# **1- Graficos Enumerativos Univariados
# DIAGRAMA DE DISPERSIÓN UNIVARIABLE**

# %% [markdown]
# ## Código Python que calcula las estadísticas descriptivas para la variable A9_Score
# incluyendo media, mediana, moda, desviación estándar y detección de valores atípicos usando el método IQR:

# %%
# GENERAR ESTADISTICAS DESCRIPTIVAS PARA LA VARIABLE ESCOGIDA

import pandas as pd

# Cargar datos
df = pd.read_csv('autism_screening.csv')

# Variable a analizar
var = 'A9_Score'

# Calcular estadísticas descriptivas
media = df[var].mean()
mediana = df[var].median()
moda = df[var].mode().iloc[0] if not df[var].mode().empty else None
std_dev = df[var].std()

# Detectar valores atípicos usando el método de IQR
Q1 = df[var].quantile(0.25)
Q3 = df[var].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = df[(df[var] < lower_bound) | (df[var] > upper_bound)][var]

# Resultados
resultados = {
    'media': media,
    'mediana': mediana,
    'moda': moda,
    'desviacion_estandar': std_dev,
    'limite_inferior_outliers': lower_bound,
    'limite_superior_outliers': upper_bound,
    'valores_atipicos': outliers.tolist()
}

print(resultados)
# Out:
# {'media': np.float64(0.32386363636363635), 'mediana': 0.0, 'moda': np.int64(0), 'desviacion_estandar': 0.4682813996812897, 'limite_inferior_outliers': np.float64(-1.5), 'limite_superior_outliers': np.float64(2.5), 'valores_atipicos': []}

# %% [markdown]
# Esto indica que la mayoría de los valores de A9_Score están concentrados cerca de cero, con poca desviación y sin valores atípicos detectados según el método IQR

# %%
# GENERAR ESTADISTICAS DESCRIPTIVAS PARA TODAS VARIABLES DEL DATASET

# Seleccionar solo columnas numéricas
num_cols = ['A1_Score','A2_Score','A3_Score','A4_Score','A5_Score','A6_Score','A7_Score','A8_Score','A9_Score','A10_Score','age','result']

# Calcular estadísticas descriptivas
desc_stats = df[num_cols].describe()
print("Descripción Básica:\n", desc_stats)

# Calcular moda
for col in num_cols:
    print(f"Moda para {col}: ", df[col].mode().values)

# Calcular medida de dispersión
for col in num_cols:
    print(f"Desviación estándar de {col}:", df[col].std())

# Calcular mediana
for col in num_cols:
    print(f"Mediana de {col}:", df[col].median())

# Detección de valores atípicos usando IQR
for col in num_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    outliers = df[(df[col] < (Q1 - 1.5 * IQR)) | (df[col] > (Q3 + 1.5 * IQR))]
    print(f"Valores atípicos por IQR en {col}: {outliers.shape} registros")

# Detección de valores atípicos con z-score
from scipy import stats
for col in num_cols:
    z_scores = np.abs(stats.zscore(df[col].dropna()))
    outliers = np.where(z_scores > 3)
    print(f"Valores atípicos por Z-score en {col}: {len(outliers[0])} registros")
# Out:
# Descripción Básica:
#           A1_Score    A2_Score    A3_Score    A4_Score    A5_Score    A6_Score  \
# count  704.000000  704.000000  704.000000  704.000000  704.000000  704.000000
# mean     0.721591    0.453125    0.457386    0.495739    0.498580    0.284091
# std      0.448535    0.498152    0.498535    0.500337    0.500353    0.451301
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      1.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#          A7_Score    A8_Score    A9_Score   A10_Score         age      result
# count  704.000000  704.000000  704.000000  704.000000  702.000000  704.000000
# mean     0.417614    0.649148    0.323864    0.573864   29.698006    4.875000
# ...

# %% [markdown]
# **Visualizar la Distribuccion de la Variable usando Histogramas, Boxplots, u otras graficas adecuadas**
#
# **HISTOGRAMA A9_SCORE**

# %% [markdown]
# La función seaborn sns.distplot() también se puede utilizar para trazar un histograma.

# %%
sns.displot(df['A9_Score'])
plt.xlabel('A9_Score')
plt.ylabel('Frecuencia')
plt.title('Histograma de A9_Score')
plt.show()

# %% [markdown]
# Visualizacion de la Distribuccion de la Variable A9_Score
# Teniendo en cuenta las enseñanzas del documento:
# https://www.analyticsvidhya.com/blog/2020/07/univariate-analysis-visualization-with-illustrations-in-python/

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Cargar datos
df = pd.read_csv('autism_screening.csv')

var = 'A9_Score'
data = df[var].dropna()

# Configuración general para los gráficos
plt.figure(figsize=(16, 20))

# 1 - Histograma
plt.subplot(5, 2, 1)
sns.histplot(data, kde=False, bins=10, color='skyblue')
plt.title('Histograma de A9_Score')
plt.xlabel('A9_Score')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# # 2 - Boxplot

# %%
# 2 - Boxplot
plt.subplot(5, 2, 2)
sns.boxplot(x=data, color='lightgreen')
plt.title('Boxplot de A9_Score')
# Out:
# Text(0.5, 1.0, 'Boxplot de A9_Score')

# %% [markdown]
# # 3 - Diagrama de dispersión univariable

# %%
# 3 - Diagrama de dispersión univariable
plt.subplot(5, 2, 3)
plt.scatter(range(len(data)), data, color='purple')
plt.title('Diagrama de dispersión univariable (A9_Score)')
plt.xlabel('Índice')
plt.ylabel('A9_Score')
# Out:
# Text(0, 0.5, 'A9_Score')

# %% [markdown]
# # 4 - Traza de líneas (con marcadores)

# %%
# 4 - Traza de líneas (con marcadores)
plt.subplot(5, 2, 4)
plt.plot(range(len(data)), data, marker='o', color='orange')
plt.title('Traza de líneas con marcadores (A9_Score)')
plt.xlabel('Índice')
plt.ylabel('A9_Score')
# Out:
# Text(0, 0.5, 'A9_Score')

# %% [markdown]
# # 5 - Parcela de franjas (Strip plot)

# %%
# 5 - Parcela de franjas (Strip plot)
plt.subplot(5, 2, 5)
sns.stripplot(x=data, color='red', jitter=True, size=4 )
plt.title('Parcela de franjas (Strip plot) de A9_Score')
# Out:
# Text(0.5, 1.0, 'Parcela de franjas (Strip plot) de A9_Score')

# %% [markdown]
# # 6 - Trama del enjambre (Swarm plot)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Cargar datos
df = pd.read_csv('autism_screening.csv')

var = 'A9_Score'
data = df[var].dropna()

# 6 - Trama del enjambre (Swarm plot)
plt.subplot(5, 2, 6)
sns.swarmplot(x=data, color='blue', size=3)
plt.title('Trama del enjambre (Swarm plot) de A9_Score')
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 70.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'Trama del enjambre (Swarm plot) de A9_Score')
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 96.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # 7 - Gráfica de densidad

# %%
# 7 - Gráfica de densidad
plt.subplot(5, 2, 7)
sns.kdeplot(data, fill=True, color='darkgreen')
plt.title('Gráfica de densidad de A9_Score')
# Out:
# Text(0.5, 1.0, 'Gráfica de densidad de A9_Score')

# %% [markdown]
# # 8 - Parcelas de alfombras (Heatmap de conteos)

# %%
# 8 - Parcelas de alfombras (Heatmap de conteos)
counts = data.value_counts().sort_index()
plt.subplot(5, 2, 8)
sns.heatmap(counts.to_frame().T, cmap='YlGnBu', cbar=False, annot=True)
plt.title('Parcelas de alfombras (Heatmap) de A9_Score')
plt.yticks([])
# Out:
# ([], [])

# %% [markdown]
# # 9 - Diagrama de caja alternativo

# %%
# 9 - Diagrama de caja alternativo
plt.subplot(5, 2, 9)
sns.boxplot(x=data, color='cyan')
plt.title('Diagrama de caja (Boxplot) alternativo de A9_Score')
# Out:
# Text(0.5, 1.0, 'Diagrama de caja (Boxplot) alternativo de A9_Score')

# %% [markdown]
# # 10 - Parámetros de violín (Violin plot)

# %%
# 10 - Parámetros de violín (Violin plot)
plt.subplot(5, 2, 10)
sns.violinplot(x=data, color='pink')
plt.title('Diagrama de violín (Violin plot) de A9_Score')

plt.tight_layout()
plt.show()

# %% [markdown]
# #3- Conclusiones del Analisis
#
# Basado en el análisis inicial del conjunto de datos de cribado de autismo y lo efectuado en este cuaderno de Jupyter, se identifican los siguientes posibles sesgos, patrones, hallazgos claves e implicaciones:
#
# **Sesgos y patrones en los datos**
#
# La distribución de género está equilibrada con 367 hombres y 337 mujeres, por lo que no hay un sesgo claro de género en los datos.
#
# La etnia tiene grupos desbalanceados: predominan personas White-European (233), seguido por Asian (123) y Middle Eastern (92), pero hay muchas categorías con pocos datos y una categoría desconocida (?) con 95 casos.
#
# La mayoría de los participantes no tienen antecedentes de ictericia (jundice) ni han usado antes la app (used_app_before).
#
# La variable "Class/ASD" está desbalanceada con 515 casos NO y 189 YES a autismo, lo cual debe considerarse al modelar.
#
# La categoría "relation" tiene 95 valores desconocidos, lo que puede influir en modelos que usan esta variable.
#
# Hay un valor atípico de edad extremadamente alto (383 años), que se debe revisar o considerar eliminar.
#
# **Hallazgos claves del análisis**
#
# La mayoría de los participantes son adultos (edad descrita como "18 and more").
#
# Las puntuaciones A1 a A10 muestran medias entre 0.28 y 0.72, reflejando patrones de respuestas diversas en las preguntas del test.
#
# La distribución desigual en etnia y en resultado (clase ASD) sugiere que el conjunto no es perfectamente representativo y podría introducir sesgos en predicciones si no se ajusta o pondera.
#
# ** Implicaciones y próximos pasos**
#
# Se recomienda eliminar o corregir valores atípicos evidentes, como la edad anómala.
#
# Evaluar y manejar categorías con muchos valores faltantes o desconocidos, como "relation" y "ethnicity".
#
# Balancear la variable objetivo (Class/ASD) si se usarán modelos predictivos para evitar sesgo hacia la clase mayoritaria.
#
# Considerar análisis más profundos con visualización para explorar correlaciones entre variables y el impacto en la clase ASD.
#
# Explorar técnicas de preprocesamiento y modelado que puedan manejar variables categóricas desbalanceadas y ausentes.
#
# Esta revisión inicial permite orientar limpieza y modelado para predicción más fiable y entendimiento del trastorno del espectro autista en este conjunto de datos.

# %% [markdown]
# #4- ANEXO: Informe de Análisis Exploratorio: Detección de Autismo en Adultos
#
# **1. Introducción y Selección de la Variable**
#
# Contexto: Este informe se basa en el conjunto de datos "Autism Screening on Adults", que contiene los resultados del cuestionario de 10 preguntas (AQ-10) para la detección del Trastorno del Espectro Autista (TEA) en adultos. El objetivo es realizar un análisis exploratorio para identificar patrones, posibles sesgos y hallazgos clave que puedan guiar futuros modelos predictivos.
#
# **Variable Seleccionada: A9_Score**
#
# Para este análisis univariado, he seleccionado la variable A9_Score. Esta variable corresponde a una de las 10 preguntas del cuestionario, que evalúa un comportamiento específico relacionado con el espectro autista. La elección se basa en su potencial para ser un fuerte indicador individual del resultado final del cribado. Analizar esta pregunta nos permitirá entender cómo un rasgo particular se distribuye en la muestra y cómo se correlaciona con la clasificación final de TEA, identificando así patrones de respuesta significativos. En tu cuaderno, esta variable ya se destacaba por su relevancia, lo cual confirmo para este análisis.
#
# **2. Código Python y Análisis Univariado**
#
# Se presenta el código completo para ser ejecutado en un entorno de Google Colab. El código carga los datos desde el archivo autism_screening.csv, realiza una limpieza básica reemplazando los valores ? por Nulos (NaN), y luego se enfoca en el análisis y visualización de la variable A9_Score.
#
# **Paso 1: Importar las librerías necesarias**
# import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# Configurar el estilo de las visualizaciones para un mejor aspecto
# sns.set_theme(style="whitegrid")
#
# **Paso 2: Cargar el conjunto de datos**
# Se reemplazan los valores '?' por NaN (Not a Number) para que Pandas los reconozca como datos faltantes.
# df = pd.read_csv('autism_screening.csv', na_values='?')
#
# **Paso 3: Inspección inicial de los datos**
# print("--- Información general del dataset ---")
# df.info()
# print("\n--- Primeras 5 filas del dataset ---")
# print(df.head())
#
#
# **Paso 4: Análisis Univariado de la variable 'A9_Score'**
# print("\n--- Análisis de la variable 'A9_Score' ---")
#
# Contar la frecuencia de cada respuesta (0 para 'No', 1 para 'Sí')
# a9_counts = df['A9_Score'].value_counts()
# print("\nDistribución de respuestas para A9_Score:")
# print(a9_counts)
#
# Crear una visualización para la distribución de A9_Score
# plt.figure(figsize=(10, 6))
# sns.countplot(x='A9_Score', data=df, palette='viridis')
# plt.title('Distribución de Respuestas para la Pregunta A9', fontsize=16)
# plt.xlabel('Puntuación en A9 (0 = No, 1 = Sí)', fontsize=12)
# plt.ylabel('Cantidad de Encuestados', fontsize=12)
# plt.xticks([0, 1], ['No', 'Sí'])
# plt.show()
#
#
# **Paso 5: Relación entre 'A9_Score' y la variable objetivo ('Class/ASD')**
# Este es un análisis bivariado, pero es crucial para entender la importancia de A9_Score.
# print("\n--- Relación entre A9_Score y el Diagnóstico de TEA (Class/ASD) ---")
#
# **Crear una tabla de contingencia para ver la relación**
# crosstab_a9 = pd.crosstab(df['A9_Score'], df['Class/ASD'])
# print("\nTabla de Contingencia:")
# print(crosstab_a9)
#
# **Crear una visualización para la tasa de diagnóstico por respuesta en A9**
# plt.figure(figsize=(10, 6))
# sns.countplot(x='A9_Score', hue='Class/ASD', data=df, palette='plasma')
# plt.title('Diagnóstico de TEA según la Respuesta en A9', fontsize=16)
# plt.xlabel('Puntuación en A9 (0 = No, 1 = Sí)', fontsize=12)
# plt.ylabel('Cantidad de Encuestados', fontsize=12)
# plt.xticks([0, 1], ['No', 'Sí'])
# plt.legend(title='Clasificación TEA')
# plt.show()
#
# **3. Descripción y Resumen de Hallazgos Clave**
#
# El análisis del código y las visualizaciones revela los siguientes puntos clave:
#
# Distribución de Respuestas: La mayoría de los encuestados (476 de 704, aproximadamente el 68%) respondieron 'NO' (puntuación 0) a la pregunta representada por A9_Score. Solo 228 personas (32%) respondieron 'SÍ' (puntuación 1).
#
# Patrón de Correlación (Hallazgo Clave): Se identifica un patrón muy fuerte entre la respuesta a la pregunta A9 y la clasificación final de TEA.
#
# De las 476 personas que respondieron 'NO' (0), solo 63 (un 13%) fueron clasificadas con TEA ('YES').
#
# De las 228 personas que respondieron 'SÍ' (1), 126 (un 55%) fueron clasificadas con TEA ('YES').
#
# Este desequilibrio demuestra que una respuesta afirmativa a la pregunta A9 está fuertemente asociada con un resultado positivo en el cribado de autismo.
#
# **4. Interpretación de los Resultados**
#
# Las visualizaciones confirman el patrón de manera clara. El primer gráfico muestra que la respuesta "NO" es más común en la muestra general. Sin embargo, el segundo gráfico es el más revelador: muestra que la probabilidad de recibir una clasificación de "YES" para TEA es drásticamente mayor si la persona respondió "SÍ" a la pregunta A9.
#
# Este hallazgo sugiere que el comportamiento o rasgo evaluado por la pregunta A9 es un indicador muy significativo dentro del test AQ-10. No es una pregunta neutral; su respuesta tiene un alto poder predictivo sobre el resultado final del cribado.
#
# **5. Implicaciones y Próximos Pasos**
#
# Implicaciones:
#
# Relevancia Clínica: El rasgo medido por A9_Score es un diferenciador clave para la detección de TEA en adultos según este conjunto de datos.
#
# Modelado Predictivo: Esta variable será una de las más importantes (o features) para cualquier modelo de machine learning que intente predecir la clasificación de TEA. Su alto valor informativo la hace indispensable.
#
# Sesgo Potencial: Aunque es un patrón útil, si el resto de las preguntas no fueran tan informativas, el resultado del test podría estar sesgado o depender en exceso de esta única pregunta.
#
# **Próximos Pasos Sugeridos**:
#
# **Análisis de Otras Variables**:
#
# Realizar el mismo análisis univariado y bivariado para las otras 9 preguntas (A1_Score a A10_Score) para identificar cuáles otras son también fuertes predictores.
#
# **Limpieza de Datos Profunda**:
#
# El análisis inicial (df.info()) muestra datos faltantes en age y ethnicity. Además, existe un valor atípico conocido en la edad (383 años). Estos datos deben ser limpiados (imputados o eliminados) antes de construir un modelo.
#
# **Análisis Multivariado**:
#
# ***Investigar cómo interactúan las variables*** . Por ejemplo:
#
# ¿La respuesta a la pregunta A9 tiene el mismo impacto en hombres y mujeres?
#
# ¿Cómo se relaciona la etnia con las puntuaciones del test?
#
# ***Construcción de un Modelo Predictivo***:
#
# Utilizar algoritmos de clasificación (como Regresión Logística, Random Forest o Gradient Boosting) para construir un modelo que prediga la variable Class/ASD utilizando las 10 preguntas y las variables demográficas como predictores.
#
# Este informe inicial confirma la importancia de la variable A9_Score y establece una hoja de ruta clara para los siguientes pasos del proyecto de predicción de TEA.

# %%
# Paso 1: Importar las librerías necesarias
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Configurar el estilo de las visualizaciones para un mejor aspecto
sns.set_theme(style="whitegrid")

# Paso 2: Cargar el conjunto de datos
# Se reemplazan los valores '?' por NaN (Not a Number) para que Pandas los reconozca como datos faltantes.
df = pd.read_csv('autism_screening.csv', na_values='?')

# Paso 3: Inspección inicial de los datos
print("--- Información general del dataset ---")
df.info()
print("\n--- Primeras 5 filas del dataset ---")
print(df.head())


# Paso 4: Análisis Univariado de la variable 'A9_Score'
print("\n--- Análisis de la variable 'A9_Score' ---")

# Contar la frecuencia de cada respuesta (0 para 'No', 1 para 'Sí')
a9_counts = df['A9_Score'].value_counts()
print("\nDistribución de respuestas para A9_Score:")
print(a9_counts)

# Crear una visualización para la distribución de A9_Score
plt.figure(figsize=(10, 6))
sns.countplot(x='A9_Score', data=df, palette='viridis')
plt.title('Distribución de Respuestas para la Pregunta A9', fontsize=16)
plt.xlabel('Puntuación en A9 (0 = No, 1 = Sí)', fontsize=12)
plt.ylabel('Cantidad de Encuestados', fontsize=12)
plt.xticks([0, 1], ['No', 'Sí'])
plt.show()


# Paso 5: Relación entre 'A9_Score' y la variable objetivo ('Class/ASD')
# Este es un análisis bivariado, pero es crucial para entender la importancia de A9_Score.
print("\n--- Relación entre A9_Score y el Diagnóstico de TEA (Class/ASD) ---")

# Crear una tabla de contingencia para ver la relación
crosstab_a9 = pd.crosstab(df['A9_Score'], df['Class/ASD'])
print("\nTabla de Contingencia:")
print(crosstab_a9)

# Crear una visualización para la tasa de diagnóstico por respuesta en A9
plt.figure(figsize=(10, 6))
sns.countplot(x='A9_Score', hue='Class/ASD', data=df, palette='plasma')
plt.title('Diagnóstico de TEA según la Respuesta en A9', fontsize=16)
plt.xlabel('Puntuación en A9 (0 = No, 1 = Sí)', fontsize=12)
plt.ylabel('Cantidad de Encuestados', fontsize=12)
plt.xticks([0, 1], ['No', 'Sí'])
plt.legend(title='Clasificación TEA')
plt.show()
# Out:
# --- Información general del dataset ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 704 entries, 0 to 703
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   A1_Score         704 non-null    int64
#  1   A2_Score         704 non-null    int64
#  2   A3_Score         704 non-null    int64
#  3   A4_Score         704 non-null    int64
#  4   A5_Score         704 non-null    int64
#  5   A6_Score         704 non-null    int64
#  6   A7_Score         704 non-null    int64
#  7   A8_Score         704 non-null    int64
#  8   A9_Score         704 non-null    int64
#  9   A10_Score        704 non-null    int64
#  10  age              702 non-null    float64
#  11  gender           704 non-null    object
#  12  ethnicity        609 non-null    object
#  13  jundice          704 non-null    object
#  14  austim           704 non-null    object
#  15  contry_of_res    704 non-null    object
# ...

# %%
! pip install ydata_profiling
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 4.6 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.1/400.1 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 19.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 19.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 19.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 3.0 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=562a1943c5f24fca29c595319e85d5df4187b443e2b033abd98951d81cd076c5
#   Stored in directory: /root/.cache/pip/wheels/5f/d4/d7/4189b07b5902ee9f3ce0dbb14909fbe8037c39d6c63ffd49c9
# Successfully built htmlmin
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.1
# ...

# %%
from ydata_profiling import ProfileReport
import pandas as pd

df=pd.read_csv('autism_screening.csv')
profile = ProfileReport(df, title="Reporte Autismo")
profile.to_notebook_iframe()
profile.to_file("DatosdeAutismo.html")
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# ...
